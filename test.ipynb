# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient({
    "backlinemd": {
        "url": "https://sackclothed-livid-noble.ngrok-free.dev/mcp",
        "transport": "streamable_http",
    }
})

tools = await client.get_tools()

# %%
tools
# Out:
# [StructuredTool(name='find_or_create_patient', description='Find an existing patient or create a new one.\n\nArgs:\n    name: Full name (will be split into first_name and last_name if provided)\n    email: Patient email address\n    phone: Patient phone number\n    first_name: Patient first name (overrides name if provided)\n    last_name: Patient last name (overrides name if provided)\n    dob: Date of birth in YYYY-MM-DD format\n    gender: Patient gender (Male, Female, Other)\n\nReturns:\n    Dict with patient_id and patient details', args_schema={'properties': {'name': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None}, 'email': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None}, 'phone': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None}, 'first_name': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None}, 'last_name': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None}, 'dob': {'anyOf': [{'type': 'strin
# ...
